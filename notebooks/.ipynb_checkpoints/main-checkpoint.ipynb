# %%
import loadStocks as ls
import featEng as fe
import pandas as pd
import ml_pytorch as mp
import plotCharts as pc
from svm import runSVM_SVR
from evaluate import *

TICKER_NAMES = ['fb']

STOCKS = ls.load_tickers_df(TICKER_NAMES, display="grid")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-e7ee5893da06> in <module>
# ----> 1 import loadStocks as ls
#       2 import featEng as fe
#       3 import pandas as pd
#       4 import ml_pytorch as mp
#       5 import plotCharts as pc
#
# ModuleNotFoundError: No module named 'loadStocks'

# %%
fe.pricePredictionFeatureEng40(STOCKS)
# Out:
# /Users/egarciagoya/Documents/final/tp-final-itba/featEng.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['future_price'] = df.loc[:, 'Close'].shift(LOOK_WINDOW)
# /Users/egarciagoya/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#                  Close     1d_abs  1d_dir     2d_abs      1d_cls      2d_cls  \
# Date
# 2013-03-08   27.959999  -0.620001       0   0.509998   28.580000   27.450001
# 2013-03-11   28.139999   0.180000       1  -0.440001   27.959999   28.580000
# 2013-03-12   27.830000  -0.309999       0  -0.129999   28.139999   27.959999
# 2013-03-13   27.080000  -0.750000       0  -1.059999   27.830000   28.139999
# 2013-03-14   27.040001  -0.039999       0  -0.789999   27.080000   27.830000
# ...                ...        ...     ...        ...         ...         ...
# 2020-01-29  223.229996   5.440002       1   8.360001  217.789993  214.869995
# 2020-01-30  209.529999 -13.699997       0  -8.259995  223.229996  217.789993
# 2020-01-31  201.910004  -7.619995       0 -21.319992  209.529999  223.229996
# 2020-02-03  204.190002   2.279999       1  -5.339996  201.910004  209.529999
# 2020-02-04  209.830002   5.639999       1   7.919998  204.190002  201.910004
#
#                 3d_cls      4d_cls      5d_cls      6d_cls      7d_cls  \
# Date
# 2013-03-08   27.520000   27.719999   27.780001   27.250000   26.870001
# 2013-03-11   27.450001   27.520000   27.719999   27.780001   27.250000
# 2013-03-12   28.580000   27.450001   27.520000   27.719999   27.780001
# 2013-03-13   27.959999   28.580000   27.450001   27.520000   27.719999
# 2013-03-14   28.139999   27.959999   28.580000   27.450001   27.520000
# ...                ...         ...         ...         ...         ...
# 2020-01-29  217.940002  219.759995  221.320007  221.440002  222.139999
# 2020-01-30  214.869995  217.940002  219.759995  221.320007  221.440002
# 2020-01-31  217.789993  214.869995  217.940002  219.759995  221.320007
# 2020-02-03  223.229996  217.789993  214.869995  217.940002  219.759995
# 2020-02-04  209.529999  223.229996  217.789993  214.869995  217.940002
#
#                 8d_cls      9d_cls     10d_cls      50d_ma   100d_ma  \
# Date
# 2013-03-08   27.389999   27.270000   27.129999   28.854800   26.2468
# 2013-03-11   26.870001   27.389999   27.270000   28.887400   26.3307
# 2013-03-12   27.250000   26.870001   27.389999   28.923000   26.4138
# 2013-03-13   27.780001   27.250000   26.870001   28.946400   26.4894
# 2013-03-14   27.719999   27.780001   27.250000   28.954800   26.5650
# ...                ...         ...         ...         ...       ...
# 2020-01-29  221.770004  221.149994  219.059998  207.350800  196.8853
# 2020-01-30  222.139999  221.770004  221.149994  207.639399  197.1057
# 2020-01-31  221.440002  222.139999  221.770004  207.729600  197.2372
# 2020-02-03  221.320007  221.440002  222.139999  207.827000  197.4174
# 2020-02-04  219.759995  221.320007  221.440002  208.073400  197.6308
#
#               200d_ma  future_price
# Date
# 2013-03-08   25.61875     75.290001
# 2013-03-11   25.58930     74.809998
# 2013-03-12   25.57345     74.570000
# 2013-03-13   25.54885     74.570000
# 2013-03-14   25.51890     75.019997
# ...               ...           ...
# 2020-01-29  192.27310    353.160004
# 2020-01-30  192.42250    352.089996
# 2020-01-31  192.53770    347.630005
# 2020-02-03  192.66475    344.459991
# 2020-02-04  192.82250    341.160004
#
# [1740 rows x 18 columns]

# %%
evalSVM_SVR(fe.pricePredictionFeatureEng40(STOCKS))
# Out:
# /Users/egarciagoya/Documents/final/tp-final-itba/featEng.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['future_price'] = df.loc[:, 'Close'].shift(LOOK_WINDOW)
# /Users/egarciagoya/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#                 y_test      y_pred  diff_pred_val  diff_pred_pct
# Date
# 2015-02-05  120.610001  116.979515       3.630486       0.030101
# 2019-03-05  261.299988  191.698814      69.601174       0.266365
# 2016-12-13  185.740005  170.531538      15.208468       0.081880
# 2017-03-06  179.529999  179.777025      -0.247026      -0.001376
# 2015-12-23  153.119995  153.606167      -0.486172      -0.003175
# ...                ...         ...            ...            ...
# 2016-11-23  182.660004  171.178255      11.481749       0.062859
# 2020-01-15  355.640015  201.280815     154.359199       0.434032
# 2017-04-25  158.850006  182.924724     -24.074718      -0.151556
# 2014-07-16  105.019997  101.971027       3.048970       0.029032
# 2013-10-07   83.800003   82.984586       0.815417       0.009731
#
# [575 rows x 4 columns]

# %%
df_1 = evalSVM_SVR(fe.pricePredictionFeatureEng40(STOCKS))
pc.plotDensityHist(df_1['diff_pred_pct'])
# Out:
# /Users/egarciagoya/Documents/final/tp-final-itba/featEng.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['future_price'] = df.loc[:, 'Close'].shift(LOOK_WINDOW)
# /Users/egarciagoya/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# /Users/egarciagoya/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
df_model_output = mp.ModelProcessorTF(fe.pricePredictionFeatureEng40(STOCKS))

# %%
varArr_1 = df_model_output.df_test_x_y['predictions']-df_model_output.df_test_x_y['future_price']

# %%
df_model_output.apply_model(mp.get_tf_adam_mse_5l_1024_512_256_128_1_relu())

# %%
varArr_2 = df_model_output.df_test_x_y['predictions']-df_model_output.df_test_x_y['future_price']

# %%
pc.plotDensityMultiple([varArr_1, varArr_2])

# %%
fe.pricePredictionFeatureEng40(STOCKS)

# %%
df_model_output.df_test_x_y

# %%
fe.pricePredictionFeatureEng40(STOCKS)
